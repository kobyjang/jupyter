# %%
import requests
from bs4 import BeautifulSoup

word = '학원'
url = 'https://stdict.korean.go.kr/search/searchResult.do?\
pageSize=10&searchKeyword={}'.format(word)
print(url)
# Out:
# https://stdict.korean.go.kr/search/searchResult.do?pageSize=10&searchKeyword=학원

# %%
# ul = soup.find('ul', class_='result')
# lis = ul.find_all('li')
# lis
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
lis = soup.find('ul','result').find_all('li')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <title>국립국어원 표준국어대사전</title>
# <!-- HEADER -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, target-densityDpi=medium-dpi" name="viewport"/>
# <meta content="telephone=no, address=no, email=no" name="format-detection"/>
# <meta content="본 누리집의 저작권은 국립국어원에 있습니다." name="copyright"/>
# <meta content="표준국어대사전" name="keywords"/>
# <meta content="[국립국어원 표준국어대사전]" name="description"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/css/jquery.mCustomScrollbar.css" rel="stylesheet" type="text/css"/>
# <link href="/css/style.css" rel="stylesheet" type="text/css"/>
# <link href="/css/sliderkit-core.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/css/sliderkit-demos.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/css/print/print-preview.css" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery-ui.css" rel="stylesheet" type="text/css"/>
# <link href="/js/jquery.remodal.css" rel="stylesheet" type="text/css"/>
# <link href="/css/video-js.css" rel="stylesheet" type="text/css"/>
# <link href="/images/common/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="/js/jquery.min.js" type="text/javascript"></script>
# <script src="/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/js/common.js" type="text/javascript"></script>
# <script src="/js/datepicker_kr.js" type="text/javascript"></script>
# <script src="/js/jquery.remodal.js" type="text/javascript"></script>
# <script src="/js/jquery.sliderkit.1.9.2.pack.js" type="text/javascript"></script>
# <script src="/js/jquery.mCustomScrollbar.concat.min.js" type="text/javascript"></script>
# <script src="/js/audiojs/audio.min.js" type="text/javascript"></script>
# <script src="/js/jsrender.js" type="text/javascript"></script>
# <script src="/js/swf_upload.js" type="text/javascript"></script>
# <script src="/js/autoComplete/DQCommon.js" type="text/javascript"></script>
# <script src="/js/print/jquery.print-preview.js" type="text/javascript"></script>
# <script src="/js/jquery.popupoverlay.js" type="text/javascript"></script>
# <script src="/js/eqneditor/clipboard.js" type="text/javascript"></script>
# <script src="/js/eqneditor/equed.js" type="text/javascript"></script>
# <script src="/js/player.js" type="text/javascript"></script>
# <script src="/js/md5/md5.js" type="text/javascript"></script>
# <script src="/js/video.js" type="text/javascript"></script>
# <script src="/js/FusionCharts.js" type="text/javascript"></script>
# <script src="/js/soundmanager2.js" type="text/javascript"></script>
# <script src="/js/jquery.cookie.js" type="text/javascript"></script>
# <script src="/js/shave.js" type="text/javascript"></script>
# <script src="/js/dropzone.js" type="text/javascript"></script>
# <script src="/js/rsa/rsa.js" type="text/javascript"></script>
# <script src="/js/rsa/jsbn.js" type="text/javascript"></script>
# <script src="/js/rsa/prng4.js" type="text/javascript"></script>
# <script src="/js/rsa/rng.js" type="text/javascript"></script>
# <!-- BODY -->
# <body class="s_none">
# <div id="skipnavi">
# <ul>
# <li><a href="#search">검색 바로가기</a></li>
# <li><a href="#content">본문 바로가기</a></li>
# </ul>
# </div>
# <div id="wrap_content">
# <script src="/js/autoComplete/index_dqAutoCompleteCommon.js" type="text/javascript"></script>
# <script type="text/javascript">
# $(document).ready(function(){
#
# 	$("form[name=mainForm]").find("input[name=searchKeyword]").keypress(function(e){
# 		if(e.keyCode === 13){
# 			if($.trim($(this).val()) != ""){
# 				e.preventDefault();
#
# 				var searchKeyword = $.trim($("form[name=mainForm]").find("input[name=searchKeyword]").val());
#
# 				if( ($.cookie("std_cookie_search") == null) || ($.cookie("std_cookie_search") == "list") || searchKeyword.indexOf("*") > -1 || searchKeyword.indexOf("?") > -1 || searchKeyword.indexOf("-") > -1 || searchKeyword.indexOf("^") > -1){
# 					$("form[name=mainForm]").attr("action", "/search/searchResult.do");
# 			    	$("form[name=mainForm]").submit();
# 				}else{
# 					$("form[name=mainForm]").attr("action", "/search/searchView.do");
# 			    	$("form[name=mainForm]").submit();
# 				}
# 			}else{
# 				alert("검색어를 입력해 주시기 바랍니다.");
# 				$("input[name=searchKeyword]").val("");
# 				$("input[name=searchKeyword]").focus();
# 				return false;
# 			}
# 		}
# 	});
#
# 	$("a.minus").on({
# 		click : function(){
# 			zoomOut();
# 		}
# 	});
#
# 	$("a.plus").on({
# 		click : function(){
# 			zoomIn();
# 		}
# 	});
#
# 	$("a.word").on({
# 		click : function(){
# 			$('.myword_pop').show();
# 			$('.myword_pop').css("opacity", 100);
# 			$('.myword_pop').css("visibility", "visible");
# 		}
# 	});
#
# 	//인쇄하기
# 	$("a.print").printPreview();
#
# 	//일러두기
# 	$("a.clip").on({
# 		click : function(){
# 			fnWindowOpen("/help/popup/entry.do", "popup_entry", 1000, 600, "yes");
# 		}
# 	});
#
# 	$(".remodal-close").on({
# 		click : function(){
# 			$(this).parent().popup('hide');
# 		}
# 	});
#
# 	if(location.pathname.indexOf("searchView.do") <= -1){
# 		fnMyWordListJob("", "");
# 	}
# });
# //메인화면
# function fnMoveMain(){
# 	document.location.href="/main/main.do";
# }
#
#
# function fnHeaderSearch(){
# 	checkSearch();
# 	if($.trim($("input[name=searchKeyword]").val()) != ""){
# 		var searchKeyword = $.trim($("form[name=mainForm]").find("input[name=searchKeyword]").val());
#
# 		if( ($.cookie("std_cookie_search") == null) || ($.cookie("std_cookie_search") == "list") || searchKeyword.indexOf("*") > -1 || searchKeyword.indexOf("?") > -1 || searchKeyword.indexOf("-") > -1 || searchKeyword.indexOf("^") > -1){
# 			$("form[name=mainForm]").attr("action", "/search/searchResult.do");
# 	    	$("form[name=mainForm]").submit();
# 		}else{
# 			$("form[name=mainForm]").attr("action", "/search/searchView.do");
# 	    	$("form[name=mainForm]").submit();
# 		}
# 	}else{
# 		alert("검색어를 입력해 주시기 바랍니다.");
# 		$("input[name=searchKeyword]").val("");
# 		$("input[name=searchKeyword]").focus();
# 	}
# }
#
# //자세히 찾기
# function fnSearchDetailWords(){
# 	document.location.href="/search/searchDetailWords.do";
# }
#
# // 화면 크기 조정
# var nowZoom = 100;
#
# //글자크기 확대 축소
# var fSize = 12;
# var lineHeightChg = 16;
# var moz = 1.00;
#
# //화명을 줄인다.
# function zoomOut() {
# 	var checkBrowserKind = CheckBrowserKind();
# 	if(checkBrowserKind == 'N' || checkBrowserKind == 'F'){
# 		moz-= 0.05;
# 		if(moz <= 0.7) moz = 0.7;
# 		nZooms();
# 	}else if(checkBrowserKind == 'O'){
# 		moz-= 0.05;
# 		if(moz <= 0.7) moz = 0.7;
# 		oZooms();
# 	}else{
# 		nowZoom = nowZoom - 10;
# 		if(nowZoom <= 70) nowZoom = 70;
# 		zooms();
# 	}
# }
#
# //화면을 늘린다.
# function zoomIn() {
# 	var checkBrowserKind = CheckBrowserKind();
# 	if(checkBrowserKind == 'N' || checkBrowserKind == 'F'){
# 		moz+= 0.05;
# 		if(moz >= 1.5) moz = 1.5;
# 		nZooms();
# 	}else if(checkBrowserKind == 'O'){
# 		moz+= 0.05;
# 		if(moz >= 1.5) moz = 1.5;
# 		oZooms();
# 	}else{
# 		nowZoom = nowZoom + 10;
# 		if(nowZoom >= 200) nowZoom = 200;
# 		zooms();
# 	}
# }
# function zoomReset(){
# 	nowZoom = 100;
# }
#
# function zooms(){
# 	$(".accessArea").css("zoom", nowZoom + "%");
# }
#
# function nZooms(){
# 	$(".accessArea").css("-moz-transform", "scale("+moz+")");
# 	$(".accessArea").css("-moz-transform-origin", "0 0");
# }
#
# function oZooms(){
# 	$(".accessArea").css("-o-transform", "scale("+moz+")");
# 	$(".accessArea").css("-o-transform-origin", "0 0");
# }
#
# //옛 한글 입력기 팝업
# function fnOpenTopOldHangle() {
# 	$("input[name=searchKeyword]").each(function(){
# 		$("#focus_name").val($(this).attr("id"));
# 	});
#
# 	fnWindowOpen("/search/popup/oldHangle.do", "popup_oldHangle", 600, 600, "yes");
# }
#
# //로그인
# function fnLoginForm(){
# 	document.location.href="/login/loginForm.do";
# }
#
# //회원 가입
# function fnMemberAdd(){
# 	document.location.href="/join/accessTerms.do";
# }
#
# //내 정보 관리
# function fnMemberView(){
# 	document.location.href = "/mypage/member/memberView.do";
# }
#
# //로그아웃
# function fnLoginOut(){
# 	document.location.href = "/login/loginLogout.do";
# }
#
# //내가 살펴본 단어
# function fnMyword(word_no){
# 	$("form[name=myWordForm]").find("input[name=word_no]").val(word_no);
# 	$("form[name=myWordForm]").attr("action", "/search/searchView.do");
#     $("form[name=myWordForm]").submit();
# }
#
# //내가 살펴본 단어 불러오기
# function fnMyWordListJob(jobType, targetData) {
#     $.ajax( {
#         url : "/search/myWordList.json",
#         type : "POST",
#         data : {jobType:jobType, targetData:targetData},
#         success : function(data) {
#         	var viewWordListStr = "";
#
#             if (data.returnData == "Y") {
#
#                 var viewWordList = data.viewWordList;
#
#                 if(viewWordList != null && viewWordList.length > 0) {
#
#                 	viewWordListStr += "<ul>";
#
#                 	for(var i=0;i<viewWordList.length;i++) {
#                 		var viewWord = viewWordList[i];
#
#                 		viewWordListStr += "<li id=\"myword_"+viewWord.word_no+"\">";
#
#                 		viewWordListStr += "<a href=\"javascript:fnMyword('"+viewWord.word_no+"');\">";
#                 		viewWordListStr += viewWord.org_word;
#
#                 		if(viewWord.sup_no != "0"){
#                 			viewWordListStr += "<sup>"+viewWord.sup_no+"</sup></a>";
#                 		}
#
#                 		viewWordListStr += "<a href=\"javascript:fnMyWordListJob('remove','"+viewWord.word_no+"')\" alt=\"삭제\" class=\"btn_del\" /></a>";
#                 		viewWordListStr += "</li>";
#                 	}
#
#                 	viewWordListStr += "</ul>";
#                 }
#             }
#
#             $(".mywrap").html(viewWordListStr);
#         },
#         error : function(xhr) {
#             $('#pageMessage').html(xhr.responseText);
#         }
#     });
# }
#
# //단어 추가
# function fnWordBookWordsAddAll(wordNo){
# 	if(""){
# 		var count = $("li[id^='myword_']").length;
#
# 		if(count > 0){
# 			$("#wordBookWordsAddAll").dialog({
# 				title: "단어 추가",
# 				width: 300, height: 250, modal: true
# 			});
# 		}
# 	}else{
# 		alert("들어가기가 필요합니다.");
#
# 		var params= $(".contentData").find("input").serializeArray();
#
# 	    $.each(params , function(i, field) {
# 	        params[i].value = $.trim((field.value));
# 	    });
#
# 	    var serializedFormParam = $.param(params);
#
# 		location.href="/login/loginForm.do?userTargetUrl="+location.pathname+"?"+encodeURIComponent(serializedFormParam);
# 	}
# }
#
# //단어장 추가
# function fnWordBookAddAll(){
# 	$("#wordBookWordsAddAll").dialog( "close" );
#
# 	$("#wordBookAddAll").dialog({
# 		title: "단어장 추가",
# 		width: 300, height: 250, modal: true
# 	});
# }
#
# //단어 추가 처리
# function fnWordBookWordsAddAllProc(type){
# 	var wordbookSeq = 0;
# 	var wordbookName = "";
# 	var wordNo = "";
#
# 	$("li[id^='myword_']").each(function(i){
# 		if(wordNo == ""){
# 			wordNo = $(this).attr("id").replace("myword_","");
# 		}else{
# 			wordNo += ","+$(this).attr("id").replace("myword_","");
# 		}
# 	});
#
# 	var checkFlag = false;
# 	//기존 단어장에 추가
# 	if(type == 1){
# 		wordbookSeq = $("select[name=select_wordbook_name_all]").val();
#
# 		checkFlag = true;
# 	//신규 단어장에 추가
# 	}else if(type == 2){
# 		wordbookName = $("input[name=wordbook_name_all]").val();
#
# 		if($.trim(wordbookName).length <= 0 ){
# 			alert("단어장 이름을 입력해 주세요.");
# 			$("input[name=wordbook_name_all]").focus();
# 		}else{
# 			checkFlag = true;
# 		}
# 	}
#
# 	if(checkFlag){
# 		$.ajax({
# 			url : "/mypage/memberWordBook/wordBookWordsAddAllData.json",
# 			type : "post",
# 			dataType : "json",
# 			async:false,
# 			data:{"wordbook_seq" : wordbookSeq, "wordbook_name" : wordbookName, "word_no" : wordNo},
# 			success : function(data) {
# 				if(data.returnData == "Y"){
# 					var selectWordBookList = data.selectWordBookList;
#
# 					if(selectWordBookList.length > 0){
#
# 						$("select[name=select_wordbook_name_all] > option").remove();
#
# 						var html = "";
#
# 						for(var i=0; i<selectWordBookList.length; i++){
# 							html+="<option value=\""+selectWordBookList[i].wordbook_seq+"\">"+selectWordBookList[i].wordbook_name+"("+selectWordBookList[i].wordbook_words_count+")</option>";
# 						}
#
# 						$("select[name=select_wordbook_name_all]").append(html);
# 					}
#
# 					if(type == 1){
# 						$("#wordBookWordsAddAll").dialog( "close" );
# 					}else if(type == 2){
# 						$("#wordBookAddAll").dialog( "close" );
# 					}
#
# 				}else if(data.returnData == "D"){
# 					alert("이미 단어장에 추가하였습니다.");
# 					if(type == 1){
# 						$("#wordBookWordsAddAll").dialog( "close" );
# 					}else if(type == 2){
# 						$("#wordBookAddAll").dialog( "close" );
# 					}
# 				}else if(data.returnData == "F"){
# 					alert("같은 단어장 이름이 존재합니다.");
# 					$("input[name=wordbook_name_all]").focus();
# 				}else{
# 					alert("오류가 발생하였습니다.");
# 					if(type == 1){
# 						$("#wordBookWordsAddAll").dialog( "close" );
# 					}else if(type == 2){
# 						$("#wordBookAddAll").dialog( "close" );
# 					}
# 				}
# 			},
# 			error : function(data) {
# 				alert("오류가 발생하였습니다.");
# 			}
# 		});
# 	}
# }
#
# //취소
# function fnDialogClose(id){
# 	$("#"+id).dialog( "close" );
# }
# </script>
# <div class="header" id="search">
# <form action="/search/searchResult.do?pageSize=10&amp;searchKeyword=%ED%95%99%EC%9B%90" autocomplete="off" id="command" method="get" name="mainForm">
# <input id="focus_name" type="hidden" value=""/>
# <input name="pageSize" type="hidden" value="10"/>
# <div class="n_search_wrap mt_10">
# <h2><a class="logo_s" href="javascript:fnMoveMain();"><img alt="국립국어원 표준국어대사전" src="/images/common/logo_s_n.png"/></a></h2>
# <fieldset><legend><label for="n_input">통합검색</label></legend>
# <div class="n_search_area">
# <div class="n_search_input"><input autocomplete="off" class="n_input" id="n_input" name="searchKeyword" onkeydown="dq_setTextbox('1',event);" onkeypress="return handleEnter(1,event);" onmousedown="dq_setTextbox('1',event);" style="ime-mode:active;" title="검색어 입력" type="text"/><a class="n_btn_search" href="javascript:fnHeaderSearch();">찾기</a></div>
# <a class="n_btn_search_detail_c" href="javascript:fnSearchDetailWords();">자세히 찾기</a>
# <script src="/js/autoComplete/index_dqAutoComplete.js" type="text/javascript"></script>
# <div class="n_auto_complete" id="autoCompleteBox" onmouseout="dq_setMouseoff();" onmouseover="dq_setMouseon();" style="display:none"></div>
# </div>
# </fieldset>
# </div>
# </form>
# <ul class="login_w2">
# <li class="line"><a class="small_btn" href="javascript:fnLoginForm();">들어가기</a></li>
# <li><a class="small_btn" href="javascript:fnMemberAdd();">회원 가입</a></li>
# </ul>
# </div>
# <div class="myword_pop" style="left: 705px; top: -38px; display: none;z-index:130;">
# <div class="header_modal" style="height: 27px;font-size:14px;line-height:28px;">
# <p style="font-size:14px;">
# 			내가 살펴본 단어
# 			<span class="right">
# <a href="/mypage/memberWordBook/wordBookList.do">내 단어장</a>
# </span>
# </p>
# </div>
# <div class="mywrap" style="width:91%"></div>
# <div style="margin:5px 5px 5px 0;text-align: right;">
# <a class="n_btn bn_gray ssmall" href="javascript:fnWordBookWordsAddAll();">
# <img alt="단어장에 추가" src="/images/common/icon_addvoca.png"/>
# 			단어장에 추가
# 		</a>
# <a class="n_btn bn_gray ssmall" href="javascript:fnMyWordListJob('removeAll','');">
# <img alt="전체 삭제" src="/images/common/icon_delall.png"/>
# 			전체 삭제
# 		</a>
# </div>
# <a class="remodal-close" href="#" style="top:5px;"></a>
# </div>
# <div id="wordBookWordsAddAll" style="display:none;z-index:150;">
# <p class="p_title2">단어장을 선택해 주세요.</p>
# <select class="w100p mt_10" name="select_wordbook_name_all">
# </select>
# <br/>
# <a href="javascript:fnWordBookAddAll();" style="float:right;">+새 단어장 추가</a>
# <br/>
# <br/>
# <div class="button_c">
# <a class="btn_word_ss mr_5" href="javascript:fnWordBookWordsAddAllProc('1');">추가</a>
# <a class="btn_cancel_ss" href="javascript:fnDialogClose('wordBookWordsAddAll');">취소</a>
# </div>
# </div>
# <div id="wordBookAddAll" style="display:none;z-index:150;">
# <p class="p_title2" style="font-size:15px;">
# 		새로운 단어장에 단어를 등록합니다.
# 		<br/>
# 		단어장 이름을 입력해 주세요.
# 	</p>
# <input class="textType w95p" name="wordbook_name_all" type="text" value=""/>
# <br/>
# <br/>
# <div class="button_c">
# <a class="btn_word_ss mr_5" href="javascript:fnWordBookWordsAddAllProc('2');">추가</a>
# <a class="btn_cancel_ss" href="javascript:fnDialogClose('wordBookAddAll');">취소</a>
# </div>
# </div>
# <form method="post" name="myWordForm">
# <input name="word_no" type="hidden"/>
# <input name="searchKeywordTo" type="hidden" value="3"/>
# </form>
# <div class="content_w">
# <div class="r_setting none">
# <a class="plus" href="#">확대하기</a>
# <a class="minus" href="#">축소하기</a>
# <a class="print" href="#">인쇄하기</a>
# <a class="wordbook" href="/mypage/memberWordBook/wordBookList.do">내 단어장</a>
# <a class="word" href="#">내가 살펴본 단어</a>
# <a class="clip" href="#">일러두기</a>
# <a class="help" href="/help/helpList.do">도움말</a>
# </div>
# <div class="contentData wrap_container">
# <div class="sub_top_area" id="sub_top_area">
# <a class="btn_search_list" href="#top" onclick="javascript:fnCookieSave('list');">목록으로 보기</a>
# <a class="btn_search_view" href="#top" onclick="javascript:fnCookieSave('view');">내용으로 보기</a>
# </div>
# <form action="/search/searchResult.do?pageSize=10&amp;searchKeyword=%ED%95%99%EC%9B%90" id="searchDataVO" method="post" name="searchResultForm">
# <input id="searchKeyword" name="searchKeyword" type="hidden" value="학원"/>
# <input id="word_no" name="word_no" type="hidden" value="0"/>
# <input name="searchKeywordTo" type="hidden" value="3"/>
# <input id="fileType" name="fileType" type="hidden" value=""/>
# <input id="fileField" name="fileField" type="hidden" value=""/>
# <input id="fileUseType" name="fileUseType" type="hidden" value=""/>
# <input id="fileUseContent" name="fileUseContent" type="hidden" value=""/>
# <input id="pageSize" name="pageSize" type="hidden" value="10"/>
# <div class="container accessArea mt_0 pt_0">
# <div class="title_line mt_40 clear2">
# <span class="tit">
# <span class="t_blue2">
#    					학원
#    					</span>
#
#    					찾기 결과 (총  4 개)
#    				</span>
# <select id="pageUnit" name="pageUnit" onchange="fnSearch(1);">
# <option selected="selected" value="10">10개씩 보기</option>
# <option value="20">20개씩 보기</option>
# <option value="30">30개씩 보기</option>
# <option value="40">40개씩 보기</option>
# <option value="50">50개씩 보기</option>
# </select>
# <a class="t_graybox_l fr btn_search_download" href="javascript:fnDownloadOpen();">사전 내려받기</a>
# <!-- 내려받기  remodal:start -->
# <div class="remodal w700" id="searchDownloadBox" style="display:none;">
# <div class="header_modal"><p>사전 내려받기</p></div>
# <div class="modal_content">
# <fieldset>
# <legend><label for="form_selectvoca"></label></legend>
# <div>
# <p class="pop_tb">내려받을 파일 형식 및 사전 항목을 선택해 주세요.</p>
# <div class="box_gray">
# <table class="tbl_info" summary="내려받기">
# <caption>내려받기</caption>
# <colgroup>
# <col width="15%"/>
# <col width="*"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row">파일 형식</th>
# <td>
# <input checked="" class="mr_5" id="file_info1" name="downloadType" onclick="fnDownloadType('excel');" type="radio" value="Excel"/><label class="mr_30" for="file_info1"><img alt="MS 엑셀" src="/images/icon/icon_xls.gif" title="excel"/></label>
# <input class="mr_5" id="file_info2" name="downloadType" onclick="fnDownloadType('hwp');" type="radio" value="Hwp"/><label class="mr_30" for="file_info2"><img alt="HWP 한글" src="/images/icon/icon_hwp.gif" title="hwp"/></label>
# <input class="mr_5" id="file_info3" name="downloadType" onclick="fnDownloadType('msword');" type="radio" value="Msword"/><label class="mr_30" for="file_info3"><img alt="MS 워드" src="/images/icon/icon_doc.gif" title="word"/></label>
# <input class="mr_5" id="file_info4" name="downloadType" onclick="fnDownloadType('text');" type="radio" value="Text"/><label class="mr_30" for="file_info4"><img alt="텍스트" src="/images/icon/icon_txt.gif" title="text"/></label>
# <input class="mr_5" id="file_info5" name="downloadType" onclick="fnDownloadType('xml');" type="radio" value="Xml"/><label class="mr_30" for="file_info5"><img alt="XML" src="/images/icon/icon_xml.gif" title="XML"/></label>
# </td>
# </tr>
# <tr>
# <th scope="row" valign="top">필수 항목</th>
# <td id="itemBox1">어휘, 품사, 뜻풀이, 용례</td>
# </tr>
# <tr>
# <th scope="row" valign="top">선택 항목</th>
# <td id="itemBox2">
# </td>
# </tr>
# </tbody>
# </table>
# <p class="pop_t">* 내려받기 버튼을 누르면 내려받기 창이 뜹니다.</p>
# <p class="pop_t">* 파일 내려받기 창이 뜨면 저장 버튼을 눌러 저장하십시오.</p>
# </div>
# </div>
# <div class="btn_c" id="downloadBtn">
# <a class="btn_word_s mr_10" href="javascript:fnSearchDownload();">내려받기</a>
# <a class="btn_cancel" href="javascript:fnPopupClose('searchDownloadBox');">취소</a>
# </div>
# </fieldset>
# </div>
# </div>
# </div>
# <ul class="result">
# <li>
# <dl>
# <dt>
# <a class="t_blue1" href="/search/searchView.do?word_no=362856&amp;searchKeywordTo=3">
# 							학원<sup>1</sup></a><span class="t_gray hanja_font">(學員)</span>「명사」
# 	    					<span style="letter-spacing:1px;line-height:25px;margin-top:5px;"><font class="dataLine"> 공부하는 인원.</font><a class="btn_allmost" href="#none" onclick="javascript:fnSearchView('362856')" style="white-space:nowrap;">전체  보기</a></span>
# </dt>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="t_blue1" href="/search/searchView.do?word_no=503671&amp;searchKeywordTo=3">
# 							학원<sup>2</sup></a><span class="t_gray hanja_font">(學院)</span>「명사」
# 	    					<span style="letter-spacing:1px;line-height:25px;margin-top:5px;"><span class="t_red1">「1」</span><font class="dataLine">『교육』 일정한 목적ㆍ교과 과정ㆍ설비ㆍ제도 및 법규에 의하여 계속적으로 학생에게 교육을 실시하는 기관.=학교.</font><a class="btn_allmost" href="#none" onclick="javascript:fnSearchView('503671')" style="white-space:nowrap;">전체  보기</a></span>
# </dt>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="t_blue1" href="/search/searchView.do?word_no=362857&amp;searchKeywordTo=3">
# 							학원<sup>3</sup></a><span class="t_gray hanja_font">(學園)</span>「명사」
# 	    					<span style="letter-spacing:1px;line-height:25px;margin-top:5px;"><span class="t_red1">「1」</span><font class="dataLine">『교육』 학교 및 기타 교육 기관을 통틀어 이르는 말.</font><a class="btn_allmost" href="#none" onclick="javascript:fnSearchView('362857')" style="white-space:nowrap;">전체  보기</a></span>
# </dt>
# </dl>
# </li>
# <li>
# <dl>
# <dt>
# <a class="t_blue1" href="/search/searchView.do?word_no=362858&amp;searchKeywordTo=3">
# 							학원<sup>4</sup></a><span class="t_gray hanja_font">(學園)</span>「명사」
# 	    					<span style="letter-spacing:1px;line-height:25px;margin-top:5px;"><font class="dataLine">『문학』 1919년에 발간된 최초의 학생 잡지. 창가, 소설 따위가 발표되어 소년ㆍ소녀들에게 처음으로 문학적인 분위기에 접하는 계기를 만들어 주었다.</font><a class="btn_allmost" href="#none" onclick="javascript:fnSearchView('362858')" style="white-space:nowrap;">전체  보기</a></span>
# </dt>
# </dl>
# </li>
# </ul>
# <!-- 따로보기 속담 검색결과 :end -->
# <div class="paging">
# <span class="on" style="margin-right:2px;">1</span>
# <input id="pageIndex" name="pageIndex" type="hidden" value="1"/>
# </div>
# <!--//검색결과 끝-->
# </div>
# </form>
# </div>
# </div>
# <div id="downloadType1" style="display:none;">
# <table class="tbl_pop no_br" style="width:90%; padding:0;" summary="선택 항목">
# <caption>선택 항목</caption>
# <tbody>
# <tr class="no_br">
# <td class="no_bd" colspan="4">
# <input checked="checked" id="searchDownload_all" name="searchDownload_all" onclick="javascript:fnCheckAll('searchDownload');" type="checkbox" value="-1"/><label for="searchDownload_all"> 전체</label>
# </td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_1" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="1"/><label for="select_1">구성 단위</label></td>
# <td class="no_bd"><input checked="checked" id="select_2" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="2"/><label for="select_2">고유어 여부</label></td>
# <td class="no_bd"><input checked="checked" id="select_3" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="3"/><label for="select_3">원어</label></td>
# <td class="no_bd"><input checked="checked" id="select_4" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="4"/><label for="select_4">어원</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_5" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="5"/><label for="select_5">주표제어</label></td>
# <td class="no_bd"><input checked="checked" id="select_6" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="6"/><label for="select_6">부표제어</label></td>
# <td class="no_bd"><input checked="checked" id="select_7" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="7"/><label for="select_7">발음</label></td>
# <td class="no_bd"><input checked="checked" id="select_8" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="8"/><label for="select_8">활용</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_9" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="9"/><label for="select_9">검색용 이형태</label></td>
# <td class="no_bd"><input checked="checked" id="select_10" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="10"/><label for="select_10">공통 문형</label></td>
# <td class="no_bd"><input checked="checked" id="select_11" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="11"/><label for="select_11">의미 문형</label></td>
# <td class="no_bd"><input checked="checked" id="select_12" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="12"/><label for="select_12">공통 문법</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_13" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="13"/><label for="select_13">의미 문법</label></td>
# <td class="no_bd"><input checked="checked" id="select_14" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="14"/><label for="select_14">범주</label></td>
# <td class="no_bd"><input checked="checked" id="select_15" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="15"/><label for="select_15">전문 분야</label></td>
# <td class="no_bd"><input checked="checked" id="select_16" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="16"/><label for="select_16">속담</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_17" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="17"/><label for="select_17">관용구</label></td>
# <td class="no_bd"><input checked="checked" id="select_18" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="18"/><label for="select_18">대역어</label></td>
# <td class="no_bd"><input checked="checked" id="select_19" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="19"/><label for="select_19">생물 분류군 정보</label></td>
# <td class="no_bd"><input checked="checked" id="select_20" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="20"/><label for="select_20">멀티미디어</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_21" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="21"/><label for="select_21">관련 어휘</label></td>
# <td class="no_bd"> </td>
# <td class="no_bd"> </td>
# <td class="no_bd"> </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div id="downloadType2" style="display:none;">
# <table class="tbl_pop no_br" style="width:90%; padding:0;" summary="선택 항목">
# <caption>선택 항목</caption>
# <tbody>
# <tr class="no_br">
# <td class="no_bd" colspan="4">
# <input checked="checked" id="searchDownload_all" name="searchDownload_all" onclick="javascript:fnCheckAll('searchDownload');" type="checkbox" value="-1"/><label for="searchDownload_all"> 전체</label>
# </td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_1" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="1"/><label for="select_1">원어</label></td>
# <td class="no_bd"><input checked="checked" id="select_2" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="2"/><label for="select_2">어원</label></td>
# <td class="no_bd"><input checked="checked" id="select_3" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="3"/><label for="select_3">주표제어</label></td>
# <td class="no_bd"><input checked="checked" id="select_4" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="4"/><label for="select_4">부표제어</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_5" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="5"/><label for="select_5">발음</label></td>
# <td class="no_bd"><input checked="checked" id="select_6" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="6"/><label for="select_6">활용</label></td>
# <td class="no_bd"><input checked="checked" id="select_7" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="7"/><label for="select_7">공통 문형</label></td>
# <td class="no_bd"><input checked="checked" id="select_8" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="8"/><label for="select_8">의미 문형</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_9" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="9"/><label for="select_9">공통 문법</label></td>
# <td class="no_bd"><input checked="checked" id="select_10" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="10"/><label for="select_10">의미 문법</label></td>
# <td class="no_bd"><input checked="checked" id="select_11" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="11"/><label for="select_11">범주</label></td>
# <td class="no_bd"><input checked="checked" id="select_12" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="12"/><label for="select_12">전문 분야</label></td>
# </tr>
# <tr class="no_br">
# <td class="no_bd"><input checked="checked" id="select_13" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="13"/><label for="select_13">속담</label></td>
# <td class="no_bd"><input checked="checked" id="select_14" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="14"/><label for="select_14">관용구</label></td>
# <td class="no_bd"><input checked="checked" id="select_15" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="15"/><label for="select_15">멀티미디어</label></td>
# <td class="no_bd"><input checked="checked" id="select_16" name="searchDownload" onclick="javascript:fnCheckCode('searchDownload');" type="checkbox" value="16"/><label for="select_16">관련 어휘</label></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div id="downloadType3" style="display:none;">
# <table class="tbl_pop no_br" style="width:90%; padding:0;" summary="선택 항목">
# <caption>선택 항목</caption>
# <tbody>
# <tr class="no_br">
# <td class="no_bd" colspan="4">
#               		어휘, 구성단위, 고유어 여부, 원어, 어원, 주표제어, 부표제어, 발음, 활용, 검색용 이형태, 품사, 공통 문형, 의미 문형, 공통 문법, 의미 문법, 뜻풀이, 용례, 범주, 전문 분야, 속담, 관용구, 대역어, 생물 분류군 정보, 멀티미디어, 관련 어휘
#               	</td>
# </tr>
# </tbody>
# </table>
# </div>
# <script type="text/javascript">
# 	$(document).ready(function() {
# 		$('#searchDownloadBox').popup();
#
# 		$(".remodal-close").on({
# 			click : function(){
# 				$(this).parent().popup('hide');
# 			}
# 		});
#
# 		$("form[name=mainForm]").find("input[name=searchKeyword]").val("학원");
#
#
# 		$("form[name=mainForm]").find("input[name=searchKeyword]").bind("focus", function(event) {
# 			$("form[name=mainForm]").find("input[name=searchKeyword]").select();
# 	    });
#
# 		$("form[name=mainForm]").find("input[name=searchKeyword]").focus();
#
# 		var searchKeyword = $("#n_input").val();
#
# 		if(searchKeyword.indexOf("*") > -1 || searchKeyword.indexOf("?") > -1 || searchKeyword.indexOf("-") > -1 || searchKeyword.indexOf("^") > -1) {
#
# 			$("#sub_top_area").hide();
# 		}
#
# 		$("input[name=searchKeyword]").focus();
#
# 		if(($.cookie("std_cookie_search") == null) || ($.cookie("std_cookie_search") == "list")){
# 			$(".btn_search_list").addClass("on");
# 			$(".btn_search_view").addClass("off");
# 		}else{
# 			$(".btn_search_list").addClass("off");
# 			$(".btn_search_view").addClass("on");
# 		}
#
# 		//말줄임 설정
# 		/* var maxheight = "30";
# 		shave('.dataLine', maxheight, {character: '...'}); */
#
# 		$("title").text("검색 결과 | 국립국어원 표준국어대사전");
# 	});
#
# 	//레이어 창 닫기
# 	function fnPopupClose(id) {
# 		$('#'+id).popup('hide');
# 	}
#
# 	//검색
# 	function fnSearch(pageNo) {
# 		$("input[name=searchFlag]").val("Y");
# 		$("input[name=pageIndex]").val(pageNo);
# 		$("form[name=searchResultForm]").attr("action", "/search/searchResult.do");
# 	    $("form[name=searchResultForm]").submit();
# 	}
#
# 	//보기
# 	function fnSearchView(word_no, native_code) {
# 		var searchKeywordTo = "3";
#
# 		if(native_code == "0") {
# 			searchKeywordTo = "3";
# 		} else if(native_code == "4") {
# 			searchKeywordTo = "2";
# 		} else if(native_code == "5") {
# 			searchKeywordTo = "1";
# 		}
#
# 		$("input[name=word_no]").val(word_no);
# 		$("input[name=searchKeywordTo]").val(searchKeywordTo);
#
# 		$("form[name=searchResultForm]").attr("action", "/search/searchView.do");
# 	    $("form[name=searchResultForm]").submit();
# 	}
#
# 	//사전 내려받기 모달창
# 	function fnDownloadOpen() {
# 		if(""){
#
# 			$("#downloadBtn").show();
#
# 			$('input:radio[name="downloadType"]:input[value="Excel"]').attr("checked", true);
#
# 			fnDownloadType("excel");
#
# 			if("4" > 0) {
# 				$('#searchDownloadBox').popup('show');
# 			} else {
# 				alert("사전 내려받기 목록이 없습니다.");
# 			}
# 		}else{
# 			alert("들어가기가 필요합니다.");
#
# 			var params= $(".wrap_container").find("input").serializeArray();
#
# 		    $.each(params , function(i, field) {
# 		        params[i].value = $.trim((field.value));
# 		    });
#
# 		    var serializedFormParam = $.param(params);
#
# 			location.href="/login/loginForm.do?userTargetUrl=/search/searchResult.do?"+encodeURIComponent(serializedFormParam);
# 		}
# 	}
#
# 	//파일 형식
# 	function fnDownloadType(type){
# 		if(type == "excel" || type == "text"){
# 			$("#itemBox1").html("어휘, 품사, 뜻풀이, 용례");
# 			$("#itemBox2").html($("#downloadType1").html());
# 			$("#itemBox2").parent().show();
# 		}else if(type == "hwp" || type == "msword"){
# 			$("#itemBox1").html("어휘, 품사, 뜻풀이, 용례");
# 			$("#itemBox2").html($("#downloadType2").html());
# 			$("#itemBox2").parent().show();
# 		}else{
# 			$("#itemBox1").html($("#downloadType3").html());
# 			$("#itemBox2").parent().hide();
# 		}
# 	}
#
# 	//사전 내려받기
# 	function fnSearchDownload() {
# 		$("#downloadBtn").hide();
#
# 		var searchDownload = "";
#
# 		$("input[name=fileType]").val($("input[name=downloadType]:checked").val());
# 		$("input[name=fileUseType]").val($("input[name=downloadUseType]:checked").val());
# 		$("input[name=fileUseContent]").val($("input[name=downloadUseContent]").val());
#
# 		var selectItemInput = $("#itemBox2").find($("input[name=searchDownload]"));
#
# 		$(selectItemInput).each(function() {
# 	        if($(this).prop("checked")) {
# 	        	if(searchDownload != "") {
# 	        		searchDownload +=",";
# 	        	}
#
# 	        	searchDownload += $(this).val();
# 	        }
# 	    });
#
# 		$("input[name=fileField]").val(searchDownload);
#
# 		var params= $(".wrap_container").find("input, select").serializeArray();
#
# 	    $.each(params , function(i, field) {
# 	        params[i].value = $.trim(encodeURIComponent(field.value));
# 	    });
#
# 	    var serializedFormParam = $.param(params);
#
# 		$.ajax({
# 			url : "/search/searchDownload.json?"+serializedFormParam+"&totalCount=4",
# 			type : "post",
# 			dataType : "json",
# 			success : function(data) {
# 				if(data.resultData == "Y"){
# 					alert("사전 내려받기가 신청되었습니다.\n'내 정보 관리' > '사전 내려받기'에서 신청한 자료를 내려 받으시기 바랍니다.");
# 				}else{
# 					alert("내려받기 요청중 오류가 발생하였습니다.\n관리자에게 문의하세요.");
# 				}
#
# 				fnPopupClose('searchDownloadBox');
# 			},
# 			error : function(data) {
# 				alert("에러가 발생하였습니다.");
# 			}
# 		});
# 	}
#
# 	//검색 방식 쿠키 저장
# 	function fnCookieSave(type){
# 		$.cookie('std_cookie_search', type, {path : '/'});
# 		fnHeaderSearch();
# 	}
#
# 	//전체 선택
# 	function fnCheckAll(name){
# 		$("input[name="+name+"]").each(function(){
# 			if ($("input[name="+name+"_all]").prop("checked")) {
# 	            $(this).prop("checked", true);
# 	        } else {
# 	            $(this).prop("checked", false);
# 	        }
# 		});
# 	}
#
# 	//개별 선택시 모두 체크 하엿을 경우
# 	function fnCheckCode(name) {
# 	    // 개별 체크
# 	    var cnt = 0;
# 	    $("input[name="+name+"]").each(function() {
# 	        if (!$(this).prop("checked")) {
# 	            cnt++;
# 	        }
# 	    });
# 	    if (cnt == 0) {
# 	        $("input[name="+name+"_all]").prop("checked", true);
# 	    } else {
# 	        $("input[name="+name+"_all]").prop("checked", false);
# 	    }
# 	}
# </script>
# </div>
# <div class="footer">
# <div class="f_wrap clear2">
# <div class="fl_t">
# <img alt="국립국어원" class="mr_10" src="/images/common/logo_korea.png"/>
# <a href="/help/helpList.do">도움말</a><a href="/join/siteTerms.do">이용 약관</a><a href="https://korean.go.kr/front/nuri/pageView.do?page_id=P000186&amp;mkn=2" target="_blank" title="개인 정보 처리 방침 새 창 열림">개인 정보 처리 방침</a><a href="/join/copyrightPolicy.do">저작권 정책</a><a href="/notice/noticeList.do">알립니다</a><a href="/openapi/openApiInfo.do">개발 지원(Open API)</a><a href="/comment/commentErrorReport.do">서비스 장애 신고</a><a class="pr_5" href="/statistic/dicStat.do">사전 통계</a></div>
# <div class="fr_t">
# <select id="footerFamilySite" name="footerFamilySite" title="국립국어원, 우리말샘, 한국어기초사전, 수어사전">
# <option value="1">국립국어원</option>
# <option value="2">우리말샘</option>
# <option value="3">한국어기초사전</option>
# <option value="4">수어사전</option>
# </select>
# <a class="btn_go mr_20" href="#footerFamilySite" onclick="javascript:fnMoveSite();" title="새창">이동</a>
# </div>
# </div>
# </div>
# <div id="captchaSound" style="display: none;"></div>
# <script type="text/javascript">
# 	//사이트 이동
# 	function fnMoveSite() {
# 		var type = $("#footerFamilySite").val();
# 		var url = "";
#
# 		if(type == "1") {
# 			url = "http://www.korean.go.kr/";
# 		} else if(type == "2") {
# 			url = "https://opendict.korean.go.kr";
# 		} else if(type == "3") {
# 			url = "https://krdict.korean.go.kr";
# 		} else if(type == "4") {
# 			url = "http://sldict.korean.go.kr/front/main/main.do";
# 		} else if(type == "5") {
# 			url = "https://opendict.korean.go.kr/m/";
# 		}
#
# 		window.open(url,'');
# 	}
# </script>
# </body>
# </html>

# %%
#링크 찾기
for li in lis:
    r_seq= li.find('a','t_blue1').find('sup').text.strip()
    print(r_seq)
    li.find('a','t_blue1').find('sup').decompose()
#     print(li.find('a', 't_blue1'))
    r_word = li.find('a','t_blue1').text.strip()
    print(r_word)
    r_link ='https://stdict.korean.go.kr' + li.find('a','t_blue1')['href']
    print(r_link)
    #     print(li.find('a', 't_blue1').text.strip())
    
    
    print('---------------------')
    
# print(len(lis))
# Out:
# 1
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=362856&searchKeywordTo=3
# ---------------------
# 2
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=503671&searchKeywordTo=3
# ---------------------
# 3
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=362857&searchKeywordTo=3
# ---------------------
# 4
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=362858&searchKeywordTo=3
# ---------------------

# %%
#한자 찾기

for li in lis:
#     print(type(li.find('span','t_gray hanja_font')))
#     print(type(li.find('span','t_gray hanja_font').text))
#     li_span = li.find('span', 't_gray hanja_fond')
    
    r_chi = li.find('span','t_gray hanja_font').text.strip()
    print(r_chi)
    r_des = li.find('font','dataLine').text.strip() 
    print(r_des)
    print('-----------------------')
    # print(len(lis))
# Out:
# (學員)
# 공부하는 인원.
# -----------------------
# (學院)
# 『교육』 일정한 목적ㆍ교과 과정ㆍ설비ㆍ제도 및 법규에 의하여 계속적으로 학생에게 교육을 실시하는 기관.=학교.
# -----------------------
# (學園)
# 『교육』 학교 및 기타 교육 기관을 통틀어 이르는 말.
# -----------------------
# (學園)
# 『문학』 1919년에 발간된 최초의 학생 잡지. 창가, 소설 따위가 발표되어 소년ㆍ소녀들에게 처음으로 문학적인 분위기에 접하는 계기를 만들어 주었다.
# -----------------------

# %%
#품사 찾기

for li in lis:
    li_dt = li.find('dt')
    li_dt.find('a','t_blue1').decompose()
    li_dt.find('span').decompose()
    li_dt.find('span').decompose()
    r_pos = li_dt.text.strip()
    print(r_pos)
    
    print('--------------------------')
# Out:
# 「명사」
# --------------------------
# 「명사」
# --------------------------
# 「명사」
# --------------------------
# 「명사」
# --------------------------

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
lis = soup.find('ul','result').find_all('li')



for li in lis:

    r_seq= li.find('a','t_blue1').find('sup').text.strip()
    print(r_seq)
    li.find('a','t_blue1').find('sup').decompose()
#     print(li.find('a', 't_blue1'))
    r_word = li.find('a','t_blue1').text.strip()
    print(r_word)
    r_link ='https://stdict.korean.go.kr' + li.find('a','t_blue1')['href']
    print(r_link)
    #     print(li.find('a', 't_blue1').text.strip())
    
    r_chi = li.find('span','t_gray hanja_font').text.strip()
    print(r_chi)
    r_des = li.find('font','dataLine').text.strip() 
    print(r_des)
    
    li_dt = li.find('dt')
    li_dt.find('a','t_blue1').decompose()
    li_dt.find('span').decompose()
    li_dt.find('span').decompose()
    r_pos = li_dt.text.strip()
    print(r_pos)
# Out:
# 1
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=362856&searchKeywordTo=3
# (學員)
# 공부하는 인원.
# 「명사」
# 2
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=503671&searchKeywordTo=3
# (學院)
# 『교육』 일정한 목적ㆍ교과 과정ㆍ설비ㆍ제도 및 법규에 의하여 계속적으로 학생에게 교육을 실시하는 기관.=학교.
# 「명사」
# 3
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=362857&searchKeywordTo=3
# (學園)
# 『교육』 학교 및 기타 교육 기관을 통틀어 이르는 말.
# 「명사」
# 4
# 학원
# https://stdict.korean.go.kr/search/searchView.do?word_no=362858&searchKeywordTo=3
# (學園)
# 『문학』 1919년에 발간된 최초의 학생 잡지. 창가, 소설 따위가 발표되어 소년ㆍ소녀들에게 처음으로 문학적인 분위기에 접하는 계기를 만들어 주었다.
# 「명사」

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
lis = soup.find('ul','result').find_all('li')

result_list = []


for li in lis:
    result_dic = {}
    
    #링크 찾기
    r_seq= li.find('a','t_blue1').find('sup').text.strip()
    result_dic['r_seq'] = r_seq
    li.find('a','t_blue1').find('sup').decompose()
#     print(li.find('a', 't_blue1'))
    r_word = li.find('a','t_blue1').text.strip()
    result_dic['r_word'] = r_word
    r_link ='https://stdict.korean.go.kr' + li.find('a','t_blue1')['href']
    result_dic['r_link'] = r_link
#     print(li.find('a', 't_blue1').text.strip())
   
    #한자 찾기
    r_chi = li.find('span','t_gray hanja_font').text.strip()
    result_dic['r_chi'] = r_chi
    r_des = li.find('font','dataLine').text.strip() 
    result_dic['r_des'] = r_des
    
    #품사 찾기
    li_dt = li.find('dt')
    li_dt.find('a','t_blue1').decompose()
    li_dt.find('span').decompose()
    li_dt.find('span').decompose()
    r_pos = li_dt.text.strip()
    result_dic['r_pos'] = r_pos
    
    result_list.append(result_dic)
    
for result in result_list:
    print(result['r_word'], end='')
    print(result['r_seq'], end='')
    print(result['r_chi'], end='')
    print(result['r_des'], end='')
    print(result['r_pos'], end='')
    print(result['r_link'], end='')
    print('---------------')
# Out:
# 학원
# 1
# (學員)
# 공부하는 인원.
# 「명사」
# https://stdict.korean.go.kr/search/searchView.do?word_no=362856&searchKeywordTo=3
# ---------------
# 학원
# 2
# (學院)
# 『교육』 일정한 목적ㆍ교과 과정ㆍ설비ㆍ제도 및 법규에 의하여 계속적으로 학생에게 교육을 실시하는 기관.=학교.
# 「명사」
# https://stdict.korean.go.kr/search/searchView.do?word_no=503671&searchKeywordTo=3
# ---------------
# 학원
# 3
# (學園)
# 『교육』 학교 및 기타 교육 기관을 통틀어 이르는 말.
# 「명사」
# https://stdict.korean.go.kr/search/searchView.do?word_no=362857&searchKeywordTo=3
# ---------------
# 학원
# 4
# (學園)
# 『문학』 1919년에 발간된 최초의 학생 잡지. 창가, 소설 따위가 발표되어 소년ㆍ소녀들에게 처음으로 문학적인 분위기에 접하는 계기를 만들어 주었다.
# 「명사」
# https://stdict.korean.go.kr/search/searchView.do?word_no=362858&searchKeywordTo=3
# ---------------

# %%
def get_word_dic(lis, s_print=False):
    
    result_list = []
    for li in lis:
        result_dic = {}

#         #링크 찾기
        r_seq= li.find('a','t_blue1').find('sup').text.strip()
        result_dic['r_seq'] = r_seq
        li.find('a','t_blue1').find('sup').decompose()
    #     print(li.find('a', 't_blue1'))
        r_word = li.find('a','t_blue1').text.strip()
        result_dic['r_word'] = r_word
        r_link ='https://stdict.korean.go.kr' + li.find('a','t_blue1')['href']
        result_dic['r_link'] = r_link
    #     print(li.find('a', 't_blue1').text.strip())

        #한자 찾기
        r_chi = li.find('span','t_gray hanja_font').text.strip()
        result_dic['r_chi'] = r_chi
        r_des = li.find('font','dataLine').text.strip() 
        result_dic['r_des'] = r_des

        #품사 찾기
        li_dt = li.find('dt')
        li_dt.find('a','t_blue1').decompose()
        li_dt.find('span').decompose()
        li_dt.find('span').decompose()
        r_pos = li_dt.text.strip()
        result_dic['r_pos'] = r_pos

        result_list.append(result_dic)
    if s_print:
        for result in result_list:
             print(result['r_word'], end='')
#           print(result['r_seq'], end='')
            print(result['r_chi'], end='')
            print(result['r_des'], end='')
            print(result['r_pos'])
            print(' ',result['r_link'])
            print('---------------')

    return result_list
# Out:
#   File "<tokenize>", line 37
#     print(result['r_chi'], end='')
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
lis = soup.find('ul','result').find_all('li')

# r_list = get_word_dic(lis, True)
r_list = get_word_dic(lis)
for result in r_list:
    print(result['r_word'], end='')
    print(result['r_seq'], end='')
    print(result['r_chi'], end='')
    print(result['r_des'], end='')
    print(result['r_pos'])
    print(' ',result['r_link'])
    print('---------------')
# Out:
# 학원1(學員)공부하는 인원.「명사」
#   https://stdict.korean.go.kr/search/searchView.do?word_no=362856&searchKeywordTo=3
# ---------------
# 학원2(學院)『교육』 일정한 목적ㆍ교과 과정ㆍ설비ㆍ제도 및 법규에 의하여 계속적으로 학생에게 교육을 실시하는 기관.=학교.「명사」
#   https://stdict.korean.go.kr/search/searchView.do?word_no=503671&searchKeywordTo=3
# ---------------
# 학원3(學園)『교육』 학교 및 기타 교육 기관을 통틀어 이르는 말.「명사」
#   https://stdict.korean.go.kr/search/searchView.do?word_no=362857&searchKeywordTo=3
# ---------------
# 학원4(學園)『문학』 1919년에 발간된 최초의 학생 잡지. 창가, 소설 따위가 발표되어 소년ㆍ소녀들에게 처음으로 문학적인 분위기에 접하는 계기를 만들어 주었다.「명사」
#   https://stdict.korean.go.kr/search/searchView.do?word_no=362858&searchKeywordTo=3
# ---------------

# %%
word = '학교'
url = 'https://stdict.korean.go.kr/search/searchResult.do?\
pageSize=10&searchKeyword={}'.format(word)
res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')

ul = soup.find('ul', 'result')
# print(ul)

if ul != None:
    lis = soup.find_all('li')
    r_list = get_word_dic(lis, True)
else:
    print('검색결과를 못찾았습니다.')
# Out:
# 학교(學校)『교육』 일정한 목적ㆍ교과 과정ㆍ설비ㆍ제도 및 법규에 의하여 계속적으로 학생에게 교육을 실시하는 기관.≒학원.「명사」https://stdict.korean.go.kr/search/searchView.do?word_no=361333&searchKeywordTo=3---------------

# %%
def get_word_dic(lis, s_print=False):
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    lis = soup.find('ul','result').find_all('li')

    result_list = []

     #링크 찾기
    for li in lis:
        result_dic = {}
        li_a =li.find('a','t_blue1')
        if li_a.find('sup') != None:
            r_seq= li_a.find('sup').text.strip()
            li_a.find('sup').decompose()
            #     result_dic['r_seq'] = r_seq
    #     li.find('a','t_blue1').find('sup').decompose()

    #     print(li.find('a', 't_blue1'))
        r_word = li_a.text.strip()
        result_dic['r_word'] = r_word
        r_link ='https://stdict.korean.go.kr' + li.find('a','t_blue1')['href']
        result_dic['r_link'] = r_link
    #     print(li.find('a', 't_blue1').text.strip())

        #한자 찾기
        r_chi = li.find('span','t_gray hanja_font').text.strip()
        result_dic['r_chi'] = r_chi
        r_des = li.find('font','dataLine').text.strip() 
        result_dic['r_des'] = r_des

        #품사 찾기
        li_dt = li.find('dt')
        li_dt.find('a','t_blue1').decompose()
        li_dt.find('span').decompose()
        li_dt.find('span').decompose()
        r_pos = li_dt.text.strip()
        result_dic['r_pos'] = r_pos

        result_list.append(result_dic)

    if s_print:   
            for result in result_list:
                print(result['r_word'], end='')
                if 'r_seq' in result.keys():
                    print(result['r_seq'], end='')
                print(result['r_chi'], end='')
                print(result['r_des'], end='')
                print(result['r_pos'], end='')
                print(result['r_link'], end='')
                print('---------------')

    return result_list

# %%
dic_1 = {'a':1 , 'b': 2 , 'c':3}

print(dic_1.keys())
print(dic_1.values())
print(type(dic_1.keys()))
'a' in dic_1.keys()
# Out:
# dict_keys(['a', 'b', 'c'])
# dict_values([1, 2, 3])
# <class 'dict_keys'>
# True
