# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.yjjob.or.kr/p/?j=23'

res = requests.get(url)
soup = BeautifulSoup(res.content, 'html.parser')
from IPython.display import Image

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>현재모집중인과정 &lt; 모집과정 &lt; 대구 국비지원 무료교육 영진직업전문학교</title>
# <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
# <meta content="e01jn" name="generator"/>
# <meta content="우리페이지(help@wooripage.co.kr)" name="author"/>
# <meta content="국비무료교육, 보일러, 용접, 전기, 제품디자인, 회계사무, 대구직업전문학교, 대구디자인학원, 대구용접학원, 대구가구학원, 대구조경학원" name="keywords"/>
# <meta content="국비무료교육, 보일러, 용접, 전기, 제품디자인, 회계사무, 대구직업전문학교, 대구디자인학원, 대구용접학원, 대구가구학원, 대구조경학원" name="description"/>
# <link href="http://www.yjjob.or.kr" rel="canonical"/>
# <meta content="website" property="og:type"/>
# <meta content="현재모집중인과정 &lt; 모집과정 &lt; 대구 국비지원 무료교육 영진직업전문학교" property="og:title"/>
# <meta content="국비무료교육, 보일러, 용접, 전기, 제품디자인, 회계사무, 대구직업전문학교, 대구디자인학원, 대구용접학원, 대구가구학원, 대구조경학원" property="og:description"/>
# <meta content="http://www.yjjob.or.kr/data/menu/LOGO_BPFBpcm7rS5ZHe2sBTmL1486629200.png" property="og:image"/>
# ...

# %%
a = '1234:1234'
# a[:-2]
a[:a.find(':')]
# Out:
# '1234'

# %%
tds = soup.find_all('td','lh_140 v_top relative')
for td in tds:
    print(td)
    print('--------')
# Out:
# <td class="lh_140 v_top relative">
# <a class="p100" href="../p/?j=58&amp;edu_code=VmtaYVUxTnJOVlpOVkU1UlZrUkJPUT09K00=" title="[경북산업직업전문학교](자동차엔진정비)자동차정비사 양성과정 (엔진, 섀시, 전기) "><em class="font11 gray">자매학교 과정 &gt; 자동차</em><br/>
# <span class="font14 bold" style="color:#ff4646;">[경북산업직업전문학교](자동차엔진정비)자동차정비사 양성과정 (엔진, 섀시, 전기) </span></a>
# <p class="tpad3">교육기간 : <em class="blue">2021.10.01</em> ~ <em class="red">2022.05.20</em></p> <!-- //////////////추가 시작 -->
# <p class="tpad5">교육시간·요일 : <span class="bold">													09:10~16:50																										(7교시) 													[월,화,수,목,금]</span></p>
# <p class="tpad5">수강료 : <span class="bold">전액무료</span></p>
# <p class="tpad5">훈련수당 : <span class="bold purple">300,000</span>원 (<span class="green bold">매달차등지급</span>)</p>
# <!-- /////////////////추가 -->
# ...

# %%
html2 = soup.select('td.p100')
for html in html2:
#     print(html.select_one('a.p100>em.font11.gray').text.strip())
    if html.find('span','red bold') 
    print(html.find('span', 'red bold'))
# Out:
#   File "C:\Users\YJ\AppData\Local\Temp/ipykernel_11468/1039064785.py", line 4
#     if html.find('span','red bold')
#                                     ^
# SyntaxError: invalid syntax

# %%
edu_s=html.find('em', 'blue')
edu_e=html.find('em', 'red')
print('교육기간 :'edu_s.text, '~',edu_e.text )| if edu_s else print('교육기간: 'edu_e.text)
# Out:
#   File "C:\Users\YJ\AppData\Local\Temp/ipykernel_11468/4267117559.py", line 3
#     print('교육기간 :'edu_s.text, '~',edu_e.text )| if edu_s else print('교육기간: 'edu_e.text)
#                   ^
# SyntaxError: invalid syntax
